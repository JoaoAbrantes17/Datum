# %%
#%pip install -e ..

# %%
from datum import Datum

# Example 1: Equities (Yahoo) — AAPL
d1 = Datum(
    tickers=["AAPL"],
    start="2019-01-01",
    end="2024-12-31",
    freq="1d",
    asset_class="Equities",
)
prices_aapl = d1.get_prices()
meta_aapl = d1.get_metadata()

print(prices_aapl.tail())
print(meta_aapl["coverage"]["AAPL"])
