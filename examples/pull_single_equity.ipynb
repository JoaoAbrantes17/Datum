# %%
#%pip install -e ..

# %%
from datum import Datum

d = Datum(
    tickers=["AAPL"],
    start="2018-01-01",
    end="2024-01-01",
    freq="1d",
)

prices = d.get_prices()
meta = d.get_metadata()

print(prices.tail())
print(meta)
