# %%
#%pip install -e ..

# %%
from datum import Datum

# Example 2: Crypto (Binance) — BTCUSDT
d2 = Datum(
    tickers=["BTCUSDT"],
    start="2019-01-01",
    end="2024-12-31",
    freq="1d",
    asset_class="Crypto",
)
prices_btc = d2.get_prices()
meta_btc = d2.get_metadata()

print(meta_btc["coverage"]["BTCUSDT"])
prices_btc.tail()
